# %%
# Libraries
import pandas as pd
import sqldf

# %%
# Read and print data as DataFrame
all_sites = pd.read_excel('data/all_sites.xlsx')
all_sites_reduced_columns = [
    "Site ID",
    "LMS Site ID",
    "TOMS Site ID",
    "Velocity Site ID",
    "Site Name",
    "Site Status",
    "Site Type"
]
all_sites = all_sites[all_sites_reduced_columns]
all_sites["Site Name"] = all_sites.apply(
    lambda x: str(x["Site Name"]).replace(str(x["Site ID"]), "").strip(), axis=1)
all_sites.head()
# Out:
#   Site ID LMS Site ID TOMS Site ID Velocity Site ID                 Site Name  \
# 0  CHI020      CHI020        CL309            CL309                   ASTALDI
# 1  AUS038      AUS038          NaN            AU314  GLENCORE - GEORGE FISHER
# 2     105         NaN          NaN              NaN  DON'T USE - STORE CLOSED
# 3     380         380          NaN              NaN       QUINTETTE COAL LTD.
# 4     345         345        CA345            CA345      DETOUR GOLD CONISTON
#
#   Site Status       Site Type
# 0      ACTIVE          MINING
# 1      ACTIVE          MINING
# 2      CLOSED  ASSOCIATE NONE
# 3      CLOSED           STORE
# 4      ACTIVE          MINING

# %%
lms_location_names = pd.read_excel('data/lms_location_names.xlsx')
lms_location_names.head()
# Out:
#   LMS Site ID            Site Name
# 0          66           Abbotsford
# 1         901           Accounting
# 2         922  Accounts Receivable
# 3         613              Acheson
# 4           7          Advertising

# %%
mtg_site_attributes = pd.read_excel('data/mtg_site_attributes.xlsx')
mtg_site_attributes_reduced_columns = [
    "Code",
    "SiteID",
    "MineType",
    "SiteType",
    "Status",
    "Commodity",
    "Locale",
    "Organization",
    "Customer",
    "Name"
]
mtg_site_attributes = mtg_site_attributes[mtg_site_attributes_reduced_columns]
mtg_site_attributes["Name"] = mtg_site_attributes["Name"].apply(
    lambda x: str(x).strip()
)
mtg_site_attributes.head()
# Out:
#      Code  SiteID MineType                   SiteType  Status Commodity  \
# 0  AU0020  AUS002      NaN     Branch / Depot / Store  Active       NaN
# 1  AU0040  AUS004      NaN     Branch / Depot / Store  Active       NaN
# 2  AU0190  AUS019      NaN  Repair / Retread Facility  Active       NaN
# 3  AU0210  AUS021      NaN      Regional Admin Office  Active       NaN
# 4  AU0240  AUS024      NaN  Repair / Retread Facility  Active       NaN
#
#       Locale         Organization  Customer                 Name
# 0  Australia           Kalgoorlie  Kal Tire           Kalgoorlie
# 1  Australia         Perth Branch  Kal Tire         Perth Branch
# 2  Australia         Perth Repair  Kal Tire         Perth Repair
# 3  Australia        Western Admin  Kal Tire        Western Admin
# 4  Australia  Muswellbrook Repair  Kal Tire  Muswellbrook Repair

# %%
r5_mrcs = pd.read_excel('data/r5_mrcs.xlsx')
r5_mrcs_reduced_columns = [
    "MRC_CODE",
    "MRC_DESC"
]
r5_mrcs = r5_mrcs[r5_mrcs_reduced_columns]
r5_mrcs["OBSOLETE"] = r5_mrcs["MRC_DESC"].apply(lambda x: "OBSOLETE" in x)
r5_mrcs["MRC_DESC"] = r5_mrcs["MRC_DESC"].apply(lambda x: x.strip())
r5_mrcs = r5_mrcs[r5_mrcs["OBSOLETE"] == False]
r5_mrcs.head()
# Out:
#   MRC_CODE                   MRC_DESC  OBSOLETE
# 0    CA324                 GREENHILLS     False
# 1    CA338                      KEARL     False
# 4        *  DEFAULT / ALL DEPARTMENTS     False
# 5    CA316                   SPARWOOD     False
# 6    CA381              COAL MOUNTAIN     False

# %%
r5_organizations = pd.read_excel('data/r5_organizations.xlsx')
r5_organizations_reduced_columns = [
    "ORG_CODE",
    "ORG_DESC",
    "ORG_UDFCHAR07"
]
r5_organizations = r5_organizations[r5_organizations_reduced_columns]
r5_organizations["ORG_DESC"] = r5_organizations.apply(
    lambda x: x["ORG_DESC"].replace(str(x["ORG_UDFCHAR07"]), ""), axis=1)
r5_organizations["RETIRED"] = r5_organizations["ORG_DESC"].apply(
    lambda x: "RETIRED" in x)
r5_organizations["OBSOLETE"] = r5_organizations["ORG_DESC"].apply(
    lambda x: "OBSOLETE" in x
)
r5_organizations["ORG_DESC"] = r5_organizations["ORG_DESC"].apply(
    lambda x: x.replace("RETIRED", "").strip())
r5_organizations = r5_organizations[r5_organizations["OBSOLETE"] == False]
r5_organizations.head()
# Out:
#       ORG_CODE                      ORG_DESC ORG_UDFCHAR07  RETIRED  OBSOLETE
# 0       AURORA             Aurora North Mine         CA379    False     False
# 1   FORT HILLS  Fort Hills Oil Sands Project         CA323    False     False
# 2  LOMAS BAYAS            Minera Lomas Bayas         CL302     True     False
# 3          HGO              Houndé Gold Mine         BF300     True     False
# 4   FFOS-Y-FRA         Ffos-y-Fran Coal Mine         GB305     True     False

# %%
common_id = pd.read_csv('data/common_id.csv')
common_id_reduced_columns = [
    "OBJ_ORG",
    "OBJ_MRC",
    "OBJ_UDFCHAR15"
]
common_id = common_id[common_id_reduced_columns]
common_id.head()
# Out:
#    OBJ_ORG OBJ_MRC OBJ_UDFCHAR15
# 0   FRANKE  CH0080        CH0080
# 1  MOATIZE  MO0012        MO0012
# 2  MOATIZE  MO0011        MO0011
# 3  DOFASCO  CA8361        CA8361
# 4  ROSEBEL  SU0010        SU0010

# %%
# import and run query
with open('querys/organizations.sql', 'r') as fp:
    organizations_query = fp.read()

with open('querys/sites.sql', 'r') as fp:
    final_query = fp.read()

r5_organizations_filled = sqldf.run(organizations_query)
r5_organizations_filled = r5_organizations_filled[r5_organizations_filled["row_num"] == 1]

result = sqldf.run(final_query)
result.to_excel('outputs/standard_location_name.xlsx')
result
# Out:
#     Site ID LMS Site ID TOMS Site ID Site Status         Site Type  \
# 0    CHI020      CHI020        CL309      ACTIVE            MINING
# 1    AUS038      AUS038         None      ACTIVE            MINING
# 2       105        None         None      CLOSED    ASSOCIATE NONE
# 3       380         380         None      CLOSED             STORE
# 4       345         345        CA345      ACTIVE            MINING
# ..      ...         ...          ...         ...               ...
# 828     874        None         None      ACTIVE             STORE
# 829     616        None         None      ACTIVE             STORE
# 830     646        None         None      ACTIVE             STORE
# 831     629        None         None      ACTIVE             STORE
# 832     783        None         None      ACTIVE  LIGHT DUTY FLEET
#
#                                     toms_org_site_name toms_mrc_site_name  \
# 0                                                 None            ASTALDI
# 1    Redpath Mining Contractors and Engineers Austr...               None
# 2                                                 None               None
# 3                                                 None               None
# 4                                                 None        DETOUR LAKE
# ..                                                 ...                ...
# 828                                               None               None
# 829                                               None               None
# 830                                               None               None
# 831                                               None               None
# 832                                               None               None
#
#                 lms_site_name            all_sites_name  \
# 0                        None                   ASTALDI
# 1    Glencore - George Fisher  GLENCORE - GEORGE FISHER
# 2                        None  DON'T USE - STORE CLOSED
# 3                        None       QUINTETTE COAL LTD.
# 4                 Detour Gold      DETOUR GOLD CONISTON
# ..                        ...                       ...
# 828                      None              MILTON STORE
# 829                      None             AIRDRIE STORE
# 830                      None              BROOKS STORE
# 831                      None             CALGARY STORE
# 832                      None    COQUITLAM FLEET CENTRE
#
#                                              site_name
# 0                                              ASTALDI
# 1    REDPATH MINING CONTRACTORS AND ENGINEERS AUSTR...
# 2                             DON'T USE - STORE CLOSED
# 3                                  QUINTETTE COAL LTD.
# 4                                          DETOUR LAKE
# ..                                                 ...
# 828                                       MILTON STORE
# 829                                      AIRDRIE STORE
# 830                                       BROOKS STORE
# 831                                      CALGARY STORE
# 832                             COQUITLAM FLEET CENTRE
#
# [833 rows x 10 columns]
